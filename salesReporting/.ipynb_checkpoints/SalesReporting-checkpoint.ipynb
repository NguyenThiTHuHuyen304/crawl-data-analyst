# %%
import pandas as pd
import os
import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import Package and load data

# %%
path = "Data/"
dataframe = pd.read_csv(path + 'sales2019_1.csv')
dataframe.head(5)
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %% [markdown]
# ### Clean and Preprocess data

# %%
## merge 12-month data
frames = []
all_length = []
data_folder = os.listdir(path)
for file in data_folder:
    filepath = path + file
    df1 = pd.read_csv(filepath)
    frames.append(df1)
    result = pd.concat(frames)
    len1_month = len(df1.index)
    all_length.append(len1_month)
df = result    
df.to_csv('anualSales2019.csv', index= False)

# %%
## Verify data 
print(sum(all_length))
# Out:
# 186850

# %%
## Add 'Month' column
df['Month'] = df['Order Date'].str[0:2]
df['Month']
# Out:
# 0        01
# 1        01
# 2        01
# 3        01
# 4        01
#          ..
# 11681    09
# 11682    09
# 11683    09
# 11684    09
# 11685    09
# Name: Month, Length: 186850, dtype: object

# %%
print(set(df['Month']))
# Out:
# {nan, '04', '03', '05', '09', '12', 'Or', '01', '08', '06', '02', '11', '10', '07'}

# %%
## Get rid of 'Nan' and 'Or' value
df = df.dropna(how='all')
df = df[df['Month'] != 'Or']
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 11681   259353    AAA Batteries (4-pack)                3       2.99
# 11682   259354                    iPhone                1        700
# 11683   259355                    iPhone                1        700
# 11684   259356    34in Ultrawide Monitor                1     379.99
# 11685   259357      USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address Month
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215    01
# ...

# %% [markdown]
# ### Reporting

# %%
## What was the best month for sales? How much was earned that month?
# Convert object --> int
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'], downcast= 'integer')
df['Price Each'] = pd.to_numeric(df['Price Each'], downcast= 'float')
df.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered       int8
# Price Each          float32
# Order Date           object
# Purchase Address     object
# Month                object
# dtype: object

# %%
## Create Sale column
df['Sale'] = df['Quantity Ordered'] * df['Price Each']
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#            Order Date                         Purchase Address Month  \
# ...

# %%
## moving column
moving_column = df.pop('Sale')
df.insert(4,'Sale', moving_column)
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#              Sale      Order Date                         Purchase Address  \
# ...

# %%
sale_value = df.groupby('Month').sum()['Sale']
sale_value
# Out:
# Month
# 01    1822256.75
# 02    2202022.50
# 03    2807100.25
# 04    3390670.25
# 05    3152606.75
# 06    2577802.25
# 07    2647775.75
# 08    2244467.75
# 09    2097560.00
# 10    3736726.75
# 11    3199603.25
# 12    4613443.50
# Name: Sale, dtype: float32

# %%
sale_value.max()
# Out:
# 4613443.5

# %%
## Make a bar plot
months = range(1,13)
plt.bar(x = months, height = sale_value)
plt.xticks(months)
plt.xlabel("Month")
plt.ylabel("Sale in USD")
plt.show()

# %% [markdown]
# ### What city has the best sale?

# %%
address_to_city = lambda address : address.split(',')[1]

# %%
df['City'] = df['Purchase Address'].apply(address_to_city)
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#              Sale      Order Date                         Purchase Address  \
# ...

# %%
Sale_value_city =  df.groupby('City').sum()['Sale']
Sale_value_city
# Out:
# City
#  Atlanta          2795498.50
#  Austin           1819581.75
#  Boston           3661642.00
#  Dallas           2767975.50
#  Los Angeles      5452571.00
#  New York City    4664317.50
#  Portland         2320490.50
#  San Francisco    8262204.00
#  Seattle          2747755.50
# Name: Sale, dtype: float32

# %%
print(Sale_value_city.max())
# Out:
# 8262204.0

# %%
cities = [city for city, sale in Sale_value_city.items()]

# %%
## make a bar plot
plt.bar(x= cities, height = Sale_value_city)
plt.xticks(cities, rotation=90, size = 8)
plt.xlabel('Cities')
plt.ylabel('Sale in USD')
plt.show()

# %% [markdown]
# ### What product sold the most? Why do you think it sold the most?

# %%
all_products = df.groupby('Product').sum()['Quantity Ordered']
all_products
# Out:
# Product
# 20in Monitor                   4129.0
# 27in 4K Gaming Monitor         6244.0
# 27in FHD Monitor               7550.0
# 34in Ultrawide Monitor         6199.0
# AA Batteries (4-pack)         27635.0
# AAA Batteries (4-pack)        31017.0
# Apple Airpods Headphones      15661.0
# Bose SoundSport Headphones    13457.0
# Flatscreen TV                  4819.0
# Google Phone                   5532.0
# LG Dryer                        646.0
# LG Washing Machine              666.0
# Lightning Charging Cable      23217.0
# Macbook Pro Laptop             4728.0
# ThinkPad Laptop                4130.0
# USB-C Charging Cable          23975.0
# Vareebadd Phone                2068.0
# Wired Headphones              20557.0
# iPhone                         6849.0
# Name: Quantity Ordered, dtype: float64

# %%
print(all_products.max())
# Out:
# 31017.0

# %%
Products = [product for product, sale in all_products.items()]
plt.bar(x = Products, height=all_products)
plt.xticks(Products, rotation = 90)
plt.xlabel('Products')
plt.ylabel('Sale in USD')
plt.show()

# %%
##price
prices = df.groupby('Product').mean()['Price Each']
print(prices)
# Out:
# Product
# 20in Monitor                   109.989998
# 27in 4K Gaming Monitor         389.989990
# 27in FHD Monitor               149.990005
# 34in Ultrawide Monitor         379.989990
# AA Batteries (4-pack)            3.840000
# AAA Batteries (4-pack)           2.990000
# Apple Airpods Headphones       150.000000
# Bose SoundSport Headphones      99.989998
# Flatscreen TV                  300.000000
# Google Phone                   600.000000
# LG Dryer                       600.000000
# LG Washing Machine             600.000000
# Lightning Charging Cable        14.950000
# Macbook Pro Laptop            1700.000000
# ThinkPad Laptop                999.989990
# USB-C Charging Cable            11.950000
# Vareebadd Phone                400.000000
# Wired Headphones                11.990000
# iPhone                         700.000000
# Name: Price Each, dtype: float32

# %%
x = Products
y1 = all_products
y2 = prices

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(x,y1,color = 'g')
ax2.plot(x,y2,'b-')

ax1.set_xticklabels(Products, rotation = 90, size = 8)
ax1.set_xlabel('Products')
ax1.set_ylabel('All_products', color = 'g')
ax2.set_ylabel('Prices', color = 'b')

plt.show()
# Out:
# <ipython-input-24-16f1977b5415>:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(Products, rotation = 90, size = 8)

# %% [markdown]
# ### What time should we diplay ads to maximize the likelihood of customer's buying product?

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Hour'] = df['Order Date'].dt.hour

# %%
Quantity_Ordered_By_Hour =  df.groupby('Hour').sum()['Quantity Ordered']
Quantity_Ordered_By_Hour
# Out:
# Hour
# 0      4428.0
# 1      2619.0
# 2      1398.0
# 3       928.0
# 4       937.0
# 5      1493.0
# 6      2810.0
# 7      4556.0
# 8      7002.0
# 9      9816.0
# 10    12308.0
# 11    14005.0
# 12    14202.0
# 13    13685.0
# 14    12362.0
# 15    11391.0
# 16    11662.0
# 17    12229.0
# 18    13802.0
# 19    14470.0
# 20    13768.0
# 21    12244.0
# 22     9899.0
# 23     7065.0
# Name: Quantity Ordered, dtype: float64

# %%
print(Quantity_Ordered_By_Hour.max())
# Out:
# 14470.0

# %%
Hours = [hour for hour, sale in Quantity_Ordered_By_Hour.items()]
plt.plot(Hours, Quantity_Ordered_By_Hour)
plt.xticks(Hours, rotation = 90, size = 8)
plt.grid()
plt.xlabel('Hours')
plt.ylabel('Quantity_Ordered')
plt.show()

# %% [markdown]
# ### What products are most often sold together?

# %%
df_dup = df[df['Order ID'].duplicated(keep=False)]
df_dup.head()
# Out:
#     Order ID                   Product  Quantity Ordered  Price Each    Sale  \
# 41    141275      USB-C Charging Cable                 1       11.95   11.95
# 42    141275          Wired Headphones                 1       11.99   11.99
# 57    141290  Apple Airpods Headphones                 1      150.00  150.00
# 58    141290     AA Batteries (4-pack)                 3        3.84   11.52
# 133   141365           Vareebadd Phone                 1      400.00  400.00
#
#              Order Date                        Purchase Address Month  \
# 41  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301    01
# 42  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301    01
# 57  2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001    01
# 58  2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001    01
# 133 2019-01-10 11:19:00  20 Dogwood St, New York City, NY 10001    01
#
#                City  Hour
# 41           Austin    16
# 42           Austin    16
# ...

# %%
groupProduct = lambda product: ','.join(product)
groupProduct(['USB-C Charging Cable', 'Wired Headphones'])
# Out:
# 'USB-C Charging Cable,Wired Headphones'

# %%
df_dup['All Products'] = df_dup.groupby('Order ID')['Product'].transform(groupProduct)
df_dup
# Out:
# <ipython-input-32-9b73ff1a0112>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dup['All Products'] = df_dup.groupby('Order ID')['Product'].transform(groupProduct)
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 41      141275      USB-C Charging Cable                 1       11.95
# 42      141275          Wired Headphones                 1       11.99
# 57      141290  Apple Airpods Headphones                 1      150.00
# 58      141290     AA Batteries (4-pack)                 3        3.84
# 133     141365           Vareebadd Phone                 1      400.00
# ...        ...                       ...               ...         ...
# ...

# %%
df_dup = df_dup[['Order ID','All Products']].drop_duplicates()
df_dup['All Products'].value_counts().head(10)
# Out:
# iPhone,Lightning Charging Cable                       882
# Google Phone,USB-C Charging Cable                     856
# iPhone,Wired Headphones                               361
# Vareebadd Phone,USB-C Charging Cable                  312
# Google Phone,Wired Headphones                         303
# iPhone,Apple Airpods Headphones                       286
# Google Phone,Bose SoundSport Headphones               161
# Vareebadd Phone,Wired Headphones                      104
# Google Phone,USB-C Charging Cable,Wired Headphones     77
# Vareebadd Phone,Bose SoundSport Headphones             60
# Name: All Products, dtype: int64
